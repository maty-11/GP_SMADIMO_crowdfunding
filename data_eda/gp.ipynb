# %%
import os
import ast
import json
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/kickstarter.csv)
df.info()
# Out:
#   Cell In[2], line 1
#     df = pd.read_csv("data/kickstarter.csv)
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df.head()
# Out:
#            id                                               name  \
# 0   386902354  MY LITTLE PONY: Friendship is Magic Rainbow Co...
# 1   632098548  How to THINK when you DRAW BOOK 9 + REPRINTS +...
# 2  1058096422                          stare down. Volumes 1 & 2
# 3   559582035  Tales of Asunda Tome + New Untamed Comic & D&D...
# 4  1828445616  Hallowed Ground - An Afterlife Horror Comic An...
#
#                                                blurb     goal   pledged state  \
# 0  The sparkliest and most iconic moments from th...  25000.0   64002.0  live
# 1  The 9th 200 PAGE BOOK of Lorenzo Etherington's...   1000.0  341824.0  live
# 2  The story of Nil, who misconstrues an enamoure...   3000.0    8581.0  live
# 3  StrangerComics PRESENTS: Deluxe Fantasy Omnibu...  10000.0   89828.0  live
# 4  A 100+ Page Horror Anthology. Twelve stories o...  35000.0   10417.0  live
#
#                                                 slug country  \
# ...

# %%
df.category = df.category.apply(lambda x: ast.literal_eval(x))
df.category.head()
# Out:
# 0    {'id': 250, 'name': 'Comic Books', 'analytics_...
# 1    {'id': 3, 'name': 'Comics', 'analytics_name': ...
# 2    {'id': 252, 'name': 'Graphic Novels', 'analyti...
# 3    {'id': 252, 'name': 'Graphic Novels', 'analyti...
# 4    {'id': 252, 'name': 'Graphic Novels', 'analyti...
# Name: category, dtype: object

# %%
df.category.iloc[0], type(df.category.iloc[0])
# Out:
# ({'id': 250,
#   'name': 'Comic Books',
#   'analytics_name': 'Comic Books',
#   'slug': 'comics/comic books',
#   'position': 2,
#   'parent_id': 3,
#   'parent_name': 'Comics',
#   'color': 16776056,
#   'urls': {'web': {'discover': 'http://www.kickstarter.com/discover/categories/comics/comic%20books'}}},
#  dict)

# %%
df.genre = df.category.apply(lambda x: x["name"])
# Out:
# /var/folders/_8/pkq07jb52zsgz95k05pdb3wm0000gn/T/ipykernel_74208/938872940.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.genre = df.category.apply(lambda x: x["name"])

# %%
df.genre.value_counts()
# Out:
# category
# Dance              1006
# Tabletop Games      843
# Photobooks          775
# Comic Books         722
# Performances        697
#                    ...
# Family                1
# Action                1
# Zines                 1
# Letterpress           1
# Literary Spaces       1
# Name: count, Length: 131, dtype: int64

# %%
df.analytics_name = df.category.apply(lambda x: x["name"])
