# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# %%
data = pd.read_csv('data/kickstarter.csv')
data.head()
# Out:
#            id                                               name  \
# 0   386902354  MY LITTLE PONY: Friendship is Magic Rainbow Co...
# 1   632098548  How to THINK when you DRAW BOOK 9 + REPRINTS +...
# 2  1058096422                          stare down. Volumes 1 & 2
# 3   559582035  Tales of Asunda Tome + New Untamed Comic & D&D...
# 4  1828445616  Hallowed Ground - An Afterlife Horror Comic An...
#
#                                                blurb     goal   pledged state  \
# 0  The sparkliest and most iconic moments from th...  25000.0   64002.0  live
# 1  The 9th 200 PAGE BOOK of Lorenzo Etherington's...   1000.0  341824.0  live
# 2  The story of Nil, who misconstrues an enamoure...   3000.0    8581.0  live
# 3  StrangerComics PRESENTS: Deluxe Fantasy Omnibu...  10000.0   89828.0  live
# 4  A 100+ Page Horror Anthology. Twelve stories o...  35000.0   10417.0  live
#
#                                                 slug country  \
# 0  my-little-pony-friendship-is-magic-rainbow-col...      US
# 1  how-to-think-when-you-draw-book-9-reprints-ink...      GB
# 2                 stare-down-webtoon-volumes-1-and-2      US
# 3    the-untamed-wishing-well-1-tales-of-asunda-tome      US
# 4                                         afterlife1      US
#
#   country_displayable_name currency  ...  \
# 0        the United States      USD  ...
# 1       the United Kingdom      GBP  ...
# 2        the United States      USD  ...
# 3        the United States      USD  ...
# 4        the United States      USD  ...
#
#                                             category  \
# 0  {'id': 250, 'name': 'Comic Books', 'analytics_...
# 1  {'id': 3, 'name': 'Comics', 'analytics_name': ...
# 2  {'id': 252, 'name': 'Graphic Novels', 'analyti...
# 3  {'id': 252, 'name': 'Graphic Novels', 'analyti...
# 4  {'id': 252, 'name': 'Graphic Novels', 'analyti...
#
#                                                video  \
# 0                                                NaN
# 1  {'id': 1413171, 'status': 'successful', 'hls':...
# 2  {'id': 1423417, 'status': 'successful', 'hls':...
# 3  {'id': 1421552, 'status': 'successful', 'hls':...
# 4                                                NaN
#
#                                              profile  spotlight  \
# 0  {'id': 5279484, 'project_id': 5279484, 'state'...      False
# 1  {'id': 5325805, 'project_id': 5325805, 'state'...      False
# 2  {'id': 5329619, 'project_id': 5329619, 'state'...      False
# 3  {'id': 5313352, 'project_id': 5313352, 'state'...      False
# 4  {'id': 5315571, 'project_id': 5315571, 'state'...      False
#
#                                                 urls  percent_funded  \
# 0  {'web': {'project': 'https://www.kickstarter.c...      256.008000
# 1  {'web': {'project': 'https://www.kickstarter.c...    34182.400000
# 2  {'web': {'project': 'https://www.kickstarter.c...      286.033333
# 3  {'web': {'project': 'https://www.kickstarter.c...      898.280000
# 4  {'web': {'project': 'https://www.kickstarter.c...       29.762857
#
#    is_liked  is_disliked  is_launched  prelaunch_activated
# 0     False        False         True                 True
# 1     False        False         True                False
# 2     False        False         True                 True
# 3     False        False         True                 True
# 4     False        False         True                 True
#
# [5 rows x 40 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17996 entries, 0 to 17995
# Data columns (total 40 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  17996 non-null  int64
#  1   name                                17996 non-null  str
#  2   blurb                               17986 non-null  str
#  3   goal                                17996 non-null  float64
#  4   pledged                             17996 non-null  float64
#  5   state                               17996 non-null  str
#  6   slug                                17996 non-null  str
#  7   country                             17996 non-null  str
#  8   country_displayable_name            17996 non-null  str
#  9   currency                            17996 non-null  str
#  10  currency_symbol                     17996 non-null  str
#  11  currency_trailing_code              17996 non-null  bool
#  12  deadline                            17996 non-null  int64
#  13  state_changed_at                    17996 non-null  int64
#  14  created_at                          17996 non-null  int64
#  15  launched_at                         17996 non-null  int64
#  16  is_in_post_campaign_pledging_phase  17996 non-null  bool
#  17  staff_pick                          17996 non-null  bool
#  18  is_starrable                        17996 non-null  bool
#  19  disable_communication               17996 non-null  bool
#  20  backers_count                       17996 non-null  int64
#  21  static_usd_rate                     17996 non-null  float64
#  22  usd_pledged                         15241 non-null  float64
#  23  converted_pledged_amount            15241 non-null  float64
#  24  fx_rate                             17996 non-null  float64
#  25  usd_exchange_rate                   15241 non-null  float64
#  26  current_currency                    17996 non-null  str
#  27  usd_type                            17996 non-null  str
#  28  creator                             17996 non-null  str
#  29  location                            17865 non-null  str
#  30  category                            17996 non-null  str
#  31  video                               13274 non-null  str
#  32  profile                             17996 non-null  str
#  33  spotlight                           17996 non-null  bool
#  34  urls                                17996 non-null  str
#  35  percent_funded                      17996 non-null  float64
#  36  is_liked                            17996 non-null  bool
#  37  is_disliked                         17996 non-null  bool
#  38  is_launched                         17996 non-null  bool
#  39  prelaunch_activated                 17996 non-null  bool
# dtypes: bool(10), float64(8), int64(6), str(16)
# memory usage: 4.3 MB

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# дубликатов нет)

# %% [markdown]
# Сначала избавимся от признаков, которые не несут для нашей задачи пользы
# удаляем:
#  6   slug - Часть URL-адреса проекта (то, что идет после домена) Используется для формирования красивых ссылок
#  10  currency_symbol - Символ валюты
#  11  currency_trailing_code - True/False Обычно значит, пишется ли символ валюты после суммы (как 100$) или до (как $100)
#  18  is_starrable - Можно ли поставить «звезду» (добавить в избранное)
#  19  disable_communication - Запрещено ли общение в комментариях (True/False)
#  21  static_usd_rate - Курс конвертации местной валюты в USD на момент создания проекта (фиксируется, чтобы курс не прыгал)
#  22  usd_pledged - Собранная сумма, пересчитанная в USD (может быть пропущена, если проект не собирал в USD)
#  23  converted_pledged_amount - Дублирует usd_pledged с учетом фиксированного курса платформы
#  25  usd_exchange_rate - Курс обмена к USD (иногда отличается от `fx_rate` методикой расчета)
#  26  current_currency - Валюта, в которой сейчас отображаются суммы на странице(везде USD)
#  27  usd_type - Тип конвертации в USD
#  29  location - Данные о городе
#  32  profile - Дополнительные настройки профиля
#  34  urls - Ссылки на веб-версию проекта и страницу наград
#  36  is_liked / 37  is_disliked Лайкнул/дизлайкнул ли текущий пользователь

# %%
data = data.drop(['slug', 'currency_symbol','currency_trailing_code','is_starrable','disable_communication','converted_pledged_amount','usd_exchange_rate','current_currency','usd_type','profile','is_liked','is_disliked','usd_pledged','location','static_usd_rate','urls'], axis=1)

# %%
data.head(5)
# Out:
#            id                                               name  \
# 0   386902354  MY LITTLE PONY: Friendship is Magic Rainbow Co...
# 1   632098548  How to THINK when you DRAW BOOK 9 + REPRINTS +...
# 2  1058096422                          stare down. Volumes 1 & 2
# 3   559582035  Tales of Asunda Tome + New Untamed Comic & D&D...
# 4  1828445616  Hallowed Ground - An Afterlife Horror Comic An...
#
#                                                blurb     goal   pledged state  \
# 0  The sparkliest and most iconic moments from th...  25000.0   64002.0  live
# 1  The 9th 200 PAGE BOOK of Lorenzo Etherington's...   1000.0  341824.0  live
# 2  The story of Nil, who misconstrues an enamoure...   3000.0    8581.0  live
# 3  StrangerComics PRESENTS: Deluxe Fantasy Omnibu...  10000.0   89828.0  live
# 4  A 100+ Page Horror Anthology. Twelve stories o...  35000.0   10417.0  live
#
#   country country_displayable_name currency    deadline  ...  staff_pick  \
# 0      US        the United States      USD  1777572005  ...        True
# 1      GB       the United Kingdom      GBP  1775502000  ...        True
# 2      US        the United States      USD  1777489656  ...        True
# 3      US        the United States      USD  1776704517  ...        True
# 4      US        the United States      USD  1776996000  ...        True
#
#    backers_count   fx_rate                                            creator  \
# 0            173  1.000000  {'id': 1690343815, 'name': 'BOOM! Studios', 's...
# 1           3926  1.320012  {'id': 1378058646, 'name': 'Lorenzo Etheringto...
# 2            119  1.000000  {'id': 769898516, 'name': 'Rocketship', 'slug'...
# 3            408  1.000000  {'id': 1182319554, 'name': 'Sebastian A. Jones...
# 4            224  1.000000  {'id': 1376978156, 'name': 'Deathline (from Li...
#
#                                             category  \
# 0  {'id': 250, 'name': 'Comic Books', 'analytics_...
# 1  {'id': 3, 'name': 'Comics', 'analytics_name': ...
# 2  {'id': 252, 'name': 'Graphic Novels', 'analyti...
# 3  {'id': 252, 'name': 'Graphic Novels', 'analyti...
# 4  {'id': 252, 'name': 'Graphic Novels', 'analyti...
#
#                                                video  spotlight  \
# 0                                                NaN      False
# 1  {'id': 1413171, 'status': 'successful', 'hls':...      False
# 2  {'id': 1423417, 'status': 'successful', 'hls':...      False
# 3  {'id': 1421552, 'status': 'successful', 'hls':...      False
# 4                                                NaN      False
#
#   percent_funded is_launched prelaunch_activated
# 0     256.008000        True                True
# 1   34182.400000        True               False
# 2     286.033333        True                True
# 3     898.280000        True                True
# 4      29.762857        True                True
#
# [5 rows x 24 columns]

# %% [markdown]
# Проверяем на пропуски:

# %%
data.isna().sum()
# Out:
# id                                       0
# name                                     0
# blurb                                   10
# goal                                     0
# pledged                                  0
# state                                    0
# country                                  0
# country_displayable_name                 0
# currency                                 0
# deadline                                 0
# state_changed_at                         0
# created_at                               0
# launched_at                              0
# is_in_post_campaign_pledging_phase       0
# staff_pick                               0
# backers_count                            0
# fx_rate                                  0
# creator                                  0
# category                                 0
# video                                 4722
# spotlight                                0
# percent_funded                           0
# is_launched                              0
# prelaunch_activated                      0
# dtype: int64

# %% [markdown]
# Пропуски в blurb значат, что просто нет описания у проекта. Такое бывает, это не ошибка. Автор просто решил, что он без описания все соберет
# Пропуски в video также не являются ошибкой. Значит, у проекта нет прикрепленного видео

# %%
data['video'] = data['video'].fillna('')  #дальше пригодится
data['blurb'] = data['blurb'].fillna('')

# %%
# перводим в формат даты то, что является датой
data['state_changed_at'] = pd.to_datetime(data['state_changed_at'],unit='s')
data['deadline'] = pd.to_datetime(data['deadline'],unit='s')
data['created_at'] = pd.to_datetime(data['created_at'],unit='s')
data['launched_at'] = pd.to_datetime(data['launched_at'],unit='s')

# %% [markdown]
# теперь раскроем все вложенные данные

# %%
data['creator']
# Out:
# 0        {'id': 1690343815, 'name': 'BOOM! Studios', 's...
# 1        {'id': 1378058646, 'name': 'Lorenzo Etheringto...
# 2        {'id': 769898516, 'name': 'Rocketship', 'slug'...
# 3        {'id': 1182319554, 'name': 'Sebastian A. Jones...
# 4        {'id': 1376978156, 'name': 'Deathline (from Li...
#                                ...
# 17991    {'id': 787851171, 'name': 'Legends of Hapax', ...
# 17992    {'id': 1263999445, 'name': 'Dungeons & Dreadno...
# 17993    {'id': 437928348, 'name': '涼宮隼十 / パトスプロジェクト', ...
# 17994    {'id': 278762704, 'name': 'ASM-Games', 'slug':...
# 17995    {'id': 1170592379, 'name': 'Ross Cowman', 'slu...
# Name: creator, Length: 17996, dtype: str

# %%
data['creator'] = data['creator'].apply(ast.literal_eval)
creator_df = pd.json_normalize(data['creator'])
creator_df
# Out:
#                id                              name                 slug  \
# 0      1690343815                     BOOM! Studios         boom-studios
# 1      1378058646               Lorenzo Etherington           thinkdraw7
# 2       769898516                        Rocketship           rocketship
# 3      1182319554                Sebastian A. Jones      sebastianajones
# 4      1376978156  Deathline (from Lifeline Comics)            deathline
# ...           ...                               ...                  ...
# 17991   787851171                  Legends of Hapax          projectapax
# 17992  1263999445           Dungeons & Dreadnoughts  dungeonndreadnought
# 17993   437928348                  涼宮隼十 / パトスプロジェクト        pathosproject
# 17994   278762704                         ASM-Games            asm-games
# 17995  1170592379                       Ross Cowman           rosscowman
#
#       is_registered is_email_verified chosen_currency is_superbacker  \
# 0              None              None            None           None
# 1              None              None            None           None
# 2              None              None            None           None
# 3              None              None            None           None
# 4              None              None            None           None
# ...             ...               ...             ...            ...
# 17991          None              None            None           None
# 17992          None              None            None           None
# 17993          None              None            None           None
# 17994          None              None            None           None
# 17995          None              None            None           None
#
#        has_admin_message_badge partner_badge  ppo_has_action  \
# 0                        False           NaN           False
# 1                        False           NaN           False
# 2                        False           NaN           False
# 3                        False           NaN            True
# 4                        False           NaN           False
# ...                        ...           ...             ...
# 17991                    False           NaN           False
# 17992                    False           NaN           False
# 17993                    False           NaN           False
# 17994                    False           NaN           False
# 17995                    False           NaN           False
#
#        backing_action_count  \
# 0                         0
# 1                         0
# 2                         0
# 3                         7
# 4                         0
# ...                     ...
# 17991                     0
# 17992                     0
# 17993                     0
# 17994                     0
# 17995                     0
#
#                                             avatar.thumb  \
# 0      https://i.kickstarter.com/assets/052/388/145/a...
# 1      https://i.kickstarter.com/assets/052/498/845/c...
# 2      https://i.kickstarter.com/assets/024/347/567/1...
# 3      https://i.kickstarter.com/assets/007/417/981/0...
# 4      https://i.kickstarter.com/assets/050/952/772/3...
# ...                                                  ...
# 17991  https://i.kickstarter.com/assets/041/228/299/8...
# 17992  https://i.kickstarter.com/assets/047/951/813/c...
# 17993  https://i.kickstarter.com/assets/045/857/675/b...
# 17994  https://i.kickstarter.com/assets/032/012/812/4...
# 17995  https://i.kickstarter.com/assets/006/046/523/9...
#
#                                             avatar.small  \
# 0      https://i.kickstarter.com/assets/052/388/145/a...
# 1      https://i.kickstarter.com/assets/052/498/845/c...
# 2      https://i.kickstarter.com/assets/024/347/567/1...
# 3      https://i.kickstarter.com/assets/007/417/981/0...
# 4      https://i.kickstarter.com/assets/050/952/772/3...
# ...                                                  ...
# 17991  https://i.kickstarter.com/assets/041/228/299/8...
# 17992  https://i.kickstarter.com/assets/047/951/813/c...
# 17993  https://i.kickstarter.com/assets/045/857/675/b...
# 17994  https://i.kickstarter.com/assets/032/012/812/4...
# 17995  https://i.kickstarter.com/assets/006/046/523/9...
#
#                                            avatar.medium  \
# 0      https://i.kickstarter.com/assets/052/388/145/a...
# 1      https://i.kickstarter.com/assets/052/498/845/c...
# 2      https://i.kickstarter.com/assets/024/347/567/1...
# 3      https://i.kickstarter.com/assets/007/417/981/0...
# 4      https://i.kickstarter.com/assets/050/952/772/3...
# ...                                                  ...
# 17991  https://i.kickstarter.com/assets/041/228/299/8...
# 17992  https://i.kickstarter.com/assets/047/951/813/c...
# 17993  https://i.kickstarter.com/assets/045/857/675/b...
# 17994  https://i.kickstarter.com/assets/032/012/812/4...
# 17995  https://i.kickstarter.com/assets/006/046/523/9...
#
#                                            urls.web.user  \
# 0       https://www.kickstarter.com/profile/boom-studios
# 1         https://www.kickstarter.com/profile/thinkdraw7
# 2         https://www.kickstarter.com/profile/rocketship
# 3      https://www.kickstarter.com/profile/sebastiana...
# 4          https://www.kickstarter.com/profile/deathline
# ...                                                  ...
# 17991    https://www.kickstarter.com/profile/projectapax
# 17992  https://www.kickstarter.com/profile/dungeonndr...
# 17993  https://www.kickstarter.com/profile/pathosproject
# 17994      https://www.kickstarter.com/profile/asm-games
# 17995     https://www.kickstarter.com/profile/rosscowman
#
#                                            urls.api.user is_ksr_admin
# 0      https://api.kickstarter.com/v1/users/169034381...          NaN
# 1      https://api.kickstarter.com/v1/users/137805864...          NaN
# 2      https://api.kickstarter.com/v1/users/769898516...          NaN
# 3      https://api.kickstarter.com/v1/users/118231955...          NaN
# 4      https://api.kickstarter.com/v1/users/137697815...          NaN
# ...                                                  ...          ...
# 17991  https://api.kickstarter.com/v1/users/787851171...          NaN
# 17992  https://api.kickstarter.com/v1/users/126399944...          NaN
# 17993  https://api.kickstarter.com/v1/users/437928348...          NaN
# 17994  https://api.kickstarter.com/v1/users/278762704...          NaN
# 17995  https://api.kickstarter.com/v1/users/117059237...          NaN
#
# [17996 rows x 17 columns]

# %% [markdown]
# добавим в наш датасет только нужные столбцы

# %%
creator_df = creator_df.add_prefix('creator_')
data = pd.concat([data, creator_df['creator_id']], axis=1)
data = pd.concat([data, creator_df['creator_name']], axis=1)
data = pd.concat([data, creator_df['creator_is_registered']], axis=1)
data = pd.concat([data, creator_df['creator_is_ksr_admin']], axis=1)
data = pd.concat([data, creator_df['creator_is_superbacker']], axis=1)

# %%
data['category'] = data['category'].apply(ast.literal_eval)
category_df = pd.json_normalize(data['category'])
category_df
# Out:
#         id            name  analytics_name                   slug  position  \
# 0      250     Comic Books     Comic Books     comics/comic books         2
# 1        3          Comics          Comics                 comics         2
# 2      252  Graphic Novels  Graphic Novels  comics/graphic novels         4
# 3      252  Graphic Novels  Graphic Novels  comics/graphic novels         4
# 4      252  Graphic Novels  Graphic Novels  comics/graphic novels         4
# ...    ...             ...             ...                    ...       ...
# 17991   35     Video Games     Video Games      games/video games         7
# 17992   34  Tabletop Games  Tabletop Games   games/tabletop games         6
# 17993   34  Tabletop Games  Tabletop Games   games/tabletop games         6
# 17994   35     Video Games     Video Games      games/video games         7
# 17995   34  Tabletop Games  Tabletop Games   games/tabletop games         6
#
#        parent_id parent_name     color  \
# 0            3.0      Comics  16776056
# 1            NaN         NaN  16776056
# 2            3.0      Comics  16776056
# 3            3.0      Comics  16776056
# 4            3.0      Comics  16776056
# ...          ...         ...       ...
# 17991       12.0       Games     51627
# 17992       12.0       Games     51627
# 17993       12.0       Games     51627
# 17994       12.0       Games     51627
# 17995       12.0       Games     51627
#
#                                        urls.web.discover
# 0      http://www.kickstarter.com/discover/categories...
# 1      http://www.kickstarter.com/discover/categories...
# 2      http://www.kickstarter.com/discover/categories...
# 3      http://www.kickstarter.com/discover/categories...
# 4      http://www.kickstarter.com/discover/categories...
# ...                                                  ...
# 17991  http://www.kickstarter.com/discover/categories...
# 17992  http://www.kickstarter.com/discover/categories...
# 17993  http://www.kickstarter.com/discover/categories...
# 17994  http://www.kickstarter.com/discover/categories...
# 17995  http://www.kickstarter.com/discover/categories...
#
# [17996 rows x 9 columns]

# %%
category_df = category_df.add_prefix('category_')
data = pd.concat([data, category_df['category_id']], axis=1)
data = pd.concat([data, category_df['category_name']], axis=1)
data = pd.concat([data, category_df['category_slug']], axis=1)
data = pd.concat([data, category_df['category_parent_id']], axis=1)
data = pd.concat([data, category_df['category_parent_name']], axis=1)

# %%
data['video']= data['video'][data['video']!=""].apply(ast.literal_eval)
video_df = pd.json_normalize(data['video'])
video_df
# Out:
#               id      status  \
# 0            NaN         NaN
# 1      1413171.0  successful
# 2      1423417.0  successful
# 3      1421552.0  successful
# 4            NaN         NaN
# ...          ...         ...
# 17991        NaN         NaN
# 17992        NaN         NaN
# 17993        NaN         NaN
# 17994        NaN         NaN
# 17995        NaN         NaN
#
#                                                      hls  \
# 0                                                    NaN
# 1      https://v2.kickstarter.com/1774905984-BtmLSvI1...
# 2      https://v2.kickstarter.com/1774901730-LMFhnhqA...
# 3      https://v2.kickstarter.com/1774982023-DW8K0B4u...
# 4                                                    NaN
# ...                                                  ...
# 17991                                                NaN
# 17992                                                NaN
# 17993                                                NaN
# 17994                                                NaN
# 17995                                                NaN
#
#                     hls_type  \
# 0                        NaN
# 1      application/x-mpegURL
# 2      application/x-mpegURL
# 3      application/x-mpegURL
# 4                        NaN
# ...                      ...
# 17991                    NaN
# 17992                    NaN
# 17993                    NaN
# 17994                    NaN
# 17995                    NaN
#
#                                                     high  \
# 0                                                    NaN
# 1      https://v2.kickstarter.com/1774905984-BtmLSvI1...
# 2      https://v2.kickstarter.com/1774901730-LMFhnhqA...
# 3      https://v2.kickstarter.com/1774982023-DW8K0B4u...
# 4                                                    NaN
# ...                                                  ...
# 17991                                                NaN
# 17992                                                NaN
# 17993                                                NaN
# 17994                                                NaN
# 17995                                                NaN
#
#                                         high_type  \
# 0                                             NaN
# 1      video/mp4; codecs="avc1.64001E, mp4a.40.2"
# 2      video/mp4; codecs="avc1.64001E, mp4a.40.2"
# 3      video/mp4; codecs="avc1.64001E, mp4a.40.2"
# 4                                             NaN
# ...                                           ...
# 17991                                         NaN
# 17992                                         NaN
# 17993                                         NaN
# 17994                                         NaN
# 17995                                         NaN
#
#                                                     base  \
# 0                                                    NaN
# 1      https://v2.kickstarter.com/1774905984-BtmLSvI1...
# 2      https://v2.kickstarter.com/1774901730-LMFhnhqA...
# 3      https://v2.kickstarter.com/1774982023-DW8K0B4u...
# 4                                                    NaN
# ...                                                  ...
# 17991                                                NaN
# 17992                                                NaN
# 17993                                                NaN
# 17994                                                NaN
# 17995                                                NaN
#
#                                         base_type tracks   width  height  \
# 0                                             NaN    NaN     NaN     NaN
# 1      video/mp4; codecs="avc1.42E01E, mp4a.40.2"     []  1280.0   720.0
# 2      video/mp4; codecs="avc1.42E01E, mp4a.40.2"     []  1280.0   720.0
# 3      video/mp4; codecs="avc1.42E01E, mp4a.40.2"     []  1280.0   720.0
# 4                                             NaN    NaN     NaN     NaN
# ...                                           ...    ...     ...     ...
# 17991                                         NaN    NaN     NaN     NaN
# 17992                                         NaN    NaN     NaN     NaN
# 17993                                         NaN    NaN     NaN     NaN
# 17994                                         NaN    NaN     NaN     NaN
# 17995                                         NaN    NaN     NaN     NaN
#
#                                                    frame
# 0                                                    NaN
# 1      https://d15chbti7ht62o.cloudfront.net/projects...
# 2      https://d15chbti7ht62o.cloudfront.net/projects...
# 3      https://d15chbti7ht62o.cloudfront.net/projects...
# 4                                                    NaN
# ...                                                  ...
# 17991                                                NaN
# 17992                                                NaN
# 17993                                                NaN
# 17994                                                NaN
# 17995                                                NaN
#
# [17996 rows x 12 columns]

# %%
video_df = video_df.add_prefix('video_')
data = pd.concat([data, video_df['video_id']], axis=1)

# %% [markdown]
# уиии такая умнички, идем дальше, надо убить все то, что разложили на части

# %%
data = data.drop(['creator','category','video'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17996 entries, 0 to 17995
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  17996 non-null  int64
#  1   name                                17996 non-null  str
#  2   blurb                               17996 non-null  str
#  3   goal                                17996 non-null  float64
#  4   pledged                             17996 non-null  float64
#  5   state                               17996 non-null  str
#  6   country                             17996 non-null  str
#  7   country_displayable_name            17996 non-null  str
#  8   currency                            17996 non-null  str
#  9   deadline                            17996 non-null  datetime64[s]
#  10  state_changed_at                    17996 non-null  datetime64[s]
#  11  created_at                          17996 non-null  datetime64[s]
#  12  launched_at                         17996 non-null  datetime64[s]
#  13  is_in_post_campaign_pledging_phase  17996 non-null  bool
#  14  staff_pick                          17996 non-null  bool
#  15  backers_count                       17996 non-null  int64
#  16  fx_rate                             17996 non-null  float64
#  17  spotlight                           17996 non-null  bool
#  18  percent_funded                      17996 non-null  float64
#  19  is_launched                         17996 non-null  bool
#  20  prelaunch_activated                 17996 non-null  bool
#  21  creator_id                          17996 non-null  int64
#  22  creator_name                        17996 non-null  str
#  23  creator_is_registered               0 non-null      object
#  24  creator_is_ksr_admin                3 non-null      object
#  25  creator_is_superbacker              0 non-null      object
#  26  category_id                         17996 non-null  int64
#  27  category_name                       17996 non-null  str
#  28  category_slug                       17996 non-null  str
#  29  category_parent_id                  14004 non-null  float64
#  30  category_parent_name                14004 non-null  str
#  31  video_id                            13274 non-null  float64
# dtypes: bool(5), datetime64[s](4), float64(6), int64(4), object(3), str(10)
# memory usage: 3.8+ MB

# %%
data.duplicated().sum()
# Out:
# np.int64(1933)

# %% [markdown]
# как так то... надо глянуть

# %%
data[data.duplicated(keep=False)].sort_values(by = 'id' )
# Out:
#                id                                               name  \
# 14888     1594224                 KeyStone A Cappella's Debut Album!
# 14587     1594224                 KeyStone A Cappella's Debut Album!
# 14025     4202650  Ron Hall's Memphis: The Rock 'n Roll Years His...
# 14912     4202650  Ron Hall's Memphis: The Rock 'n Roll Years His...
# 15336     4202650  Ron Hall's Memphis: The Rock 'n Roll Years His...
# ...           ...                                                ...
# 9421   2143246629      Into The Well: Reclaiming the Stage as Sacred
# 16023  2145544279                                   Future Boyfriend
# 5745   2145544279                                   Future Boyfriend
# 7775   2146767304                                       Unmethodical
# 7773   2146767304                                       Unmethodical
#
#                                                    blurb     goal  pledged  \
# 14888  KeyStone A Cappella is recording our debut alb...   5000.0   8173.0
# 14587  KeyStone A Cappella is recording our debut alb...   5000.0   8173.0
# 14025  Ron Hall's newest Memphis history book product...   3000.0   3063.0
# 14912  Ron Hall's newest Memphis history book product...   3000.0   3063.0
# 15336  Ron Hall's newest Memphis history book product...   3000.0   3063.0
# ...                                                  ...      ...      ...
# 9421   Immersive dance production: A psychosexual thr...  45000.0  45021.0
# 16023  A short comedic film about falling in love in ...  10000.0  12645.0
# 5745   A short comedic film about falling in love in ...  10000.0  12645.0
# 7775   A collection of some of my favorite photograph...    250.0    545.0
# 7773   A collection of some of my favorite photograph...    250.0    545.0
#
#             state country country_displayable_name currency  \
# 14888  successful      US        the United States      USD
# 14587  successful      US        the United States      USD
# 14025  successful      US        the United States      USD
# 14912  successful      US        the United States      USD
# 15336  successful      US        the United States      USD
# ...           ...     ...                      ...      ...
# 9421   successful      US        the United States      USD
# 16023  successful      US        the United States      USD
# 5745   successful      US        the United States      USD
# 7775   successful      US        the United States      USD
# 7773   successful      US        the United States      USD
#
#                  deadline  ...                  creator_name  \
# 14888 2014-09-01 03:59:00  ...           KeyStone A Cappella
# 14587 2014-09-01 03:59:00  ...           KeyStone A Cappella
# 14025 2014-05-09 03:21:16  ...              Sherman Willmott
# 14912 2014-05-09 03:21:16  ...              Sherman Willmott
# 15336 2014-05-09 03:21:16  ...              Sherman Willmott
# ...                   ...  ...                           ...
# 9421  2025-07-20 14:10:37  ...               Sabina Lundgren
# 16023 2014-08-05 07:00:00  ...  Emily Bell and Ron Morehouse
# 5745  2014-08-05 07:00:00  ...  Emily Bell and Ron Morehouse
# 7775  2021-05-31 01:00:00  ...                   Brian White
# 7773  2021-05-31 01:00:00  ...                   Brian White
#
#       creator_is_registered creator_is_ksr_admin  creator_is_superbacker  \
# 14888                  None                  NaN                    None
# 14587                  None                  NaN                    None
# 14025                  None                  NaN                    None
# 14912                  None                  NaN                    None
# 15336                  None                  NaN                    None
# ...                     ...                  ...                     ...
# 9421                   None                  NaN                    None
# 16023                  None                  NaN                    None
# 5745                   None                  NaN                    None
# 7775                   None                  NaN                    None
# 7773                   None                  NaN                    None
#
#        category_id  category_name        category_slug  category_parent_id  \
# 14888           14          Music                music                 NaN
# 14587           14          Music                music                 NaN
# 14025           43           Rock           music/rock                14.0
# 14912           43           Rock           music/rock                14.0
# 15336           43           Rock           music/rock                14.0
# ...            ...            ...                  ...                 ...
# 9421           255    Residencies    dance/residencies                 6.0
# 16023          292         Comedy  film & video/comedy                11.0
# 5745           292         Comedy  film & video/comedy                11.0
# 7775           277         Nature   photography/nature                15.0
# 7773           277         Nature   photography/nature                15.0
#
#        category_parent_name   video_id
# 14888                   NaN   406027.0
# 14587                   NaN   406027.0
# 14025                 Music   352428.0
# 14912                 Music   352428.0
# 15336                 Music   352428.0
# ...                     ...        ...
# 9421                  Dance  1366756.0
# 16023          Film & Video   412770.0
# 5745           Film & Video   412770.0
# 7775            Photography        NaN
# 7773            Photography        NaN
#
# [3783 rows x 32 columns]

# %% [markdown]
# в строках были различия только внуутри словарей, но по сути проекты идентичны, так что придется поудалять дубли

# %%
data = data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16063 entries, 0 to 17995
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  16063 non-null  int64
#  1   name                                16063 non-null  str
#  2   blurb                               16063 non-null  str
#  3   goal                                16063 non-null  float64
#  4   pledged                             16063 non-null  float64
#  5   state                               16063 non-null  str
#  6   country                             16063 non-null  str
#  7   country_displayable_name            16063 non-null  str
#  8   currency                            16063 non-null  str
#  9   deadline                            16063 non-null  datetime64[s]
#  10  state_changed_at                    16063 non-null  datetime64[s]
#  11  created_at                          16063 non-null  datetime64[s]
#  12  launched_at                         16063 non-null  datetime64[s]
#  13  is_in_post_campaign_pledging_phase  16063 non-null  bool
#  14  staff_pick                          16063 non-null  bool
#  15  backers_count                       16063 non-null  int64
#  16  fx_rate                             16063 non-null  float64
#  17  spotlight                           16063 non-null  bool
#  18  percent_funded                      16063 non-null  float64
#  19  is_launched                         16063 non-null  bool
#  20  prelaunch_activated                 16063 non-null  bool
#  21  creator_id                          16063 non-null  int64
#  22  creator_name                        16063 non-null  str
#  23  creator_is_registered               0 non-null      object
#  24  creator_is_ksr_admin                3 non-null      object
#  25  creator_is_superbacker              0 non-null      object
#  26  category_id                         16063 non-null  int64
#  27  category_name                       16063 non-null  str
#  28  category_slug                       16063 non-null  str
#  29  category_parent_id                  12638 non-null  float64
#  30  category_parent_name                12638 non-null  str
#  31  video_id                            11584 non-null  float64
# dtypes: bool(5), datetime64[s](4), float64(6), int64(4), object(3), str(10)
# memory usage: 3.5+ MB

# %%
data.isna().sum()
# Out:
# id                                        0
# name                                      0
# blurb                                     0
# goal                                      0
# pledged                                   0
# state                                     0
# country                                   0
# country_displayable_name                  0
# currency                                  0
# deadline                                  0
# state_changed_at                          0
# created_at                                0
# launched_at                               0
# is_in_post_campaign_pledging_phase        0
# staff_pick                                0
# backers_count                             0
# fx_rate                                   0
# spotlight                                 0
# percent_funded                            0
# is_launched                               0
# prelaunch_activated                       0
# creator_id                                0
# creator_name                              0
# creator_is_registered                 16063
# creator_is_ksr_admin                  16060
# creator_is_superbacker                16063
# category_id                               0
# category_name                             0
# category_slug                             0
# category_parent_id                     3425
# category_parent_name                   3425
# video_id                               4479
# dtype: int64

# %% [markdown]
# в столбцах  creator_is_registered и creator_is_superbacker полностью пусто, здесь creator_is_ksr_admin всего три значения. Совершенно не нужны нам((
#
#   category_parent_id,category_parent_name - здесь пустоты, потому что категория является родителем сама по себе, поэтому ни на кого не ссылкается. Поэтому проставим здесь 0, так "мама" категория

# %%
data = data.drop(['creator_is_registered','creator_is_superbacker','creator_is_ksr_admin'], axis=1)

# %%
data['category_parent_id'] = data['category_parent_id'].fillna(0)
data['category_parent_name'] = data['category_parent_name'].fillna("0")

# %%
data.isna().sum()
# Out:
# id                                       0
# name                                     0
# blurb                                    0
# goal                                     0
# pledged                                  0
# state                                    0
# country                                  0
# country_displayable_name                 0
# currency                                 0
# deadline                                 0
# state_changed_at                         0
# created_at                               0
# launched_at                              0
# is_in_post_campaign_pledging_phase       0
# staff_pick                               0
# backers_count                            0
# fx_rate                                  0
# spotlight                                0
# percent_funded                           0
# is_launched                              0
# prelaunch_activated                      0
# creator_id                               0
# creator_name                             0
# category_id                              0
# category_name                            0
# category_slug                            0
# category_parent_id                       0
# category_parent_name                     0
# video_id                              4479
# dtype: int64

# %%
data
# Out:
#                id                                               name  \
# 0       386902354  MY LITTLE PONY: Friendship is Magic Rainbow Co...
# 1       632098548  How to THINK when you DRAW BOOK 9 + REPRINTS +...
# 2      1058096422                          stare down. Volumes 1 & 2
# 3       559582035  Tales of Asunda Tome + New Untamed Comic & D&D...
# 4      1828445616  Hallowed Ground - An Afterlife Horror Comic An...
# ...           ...                                                ...
# 17991   319939511  Legends of Hapax: the new turn-based RPG gener...
# 17992  1792472318            Grimdark Battlefleet: Fleets of Midgard
# 17993   570470125       想刃のデュアレイド / Dual Blade of Postmortem Desires
# 17994  1054211112  Oaths of Light - a 3D jrpg game where player c...
# 17995   840223440                              BFF! The Golden Years
#
#                                                    blurb     goal   pledged  \
# 0      The sparkliest and most iconic moments from th...  25000.0   64002.0
# 1      The 9th 200 PAGE BOOK of Lorenzo Etherington's...   1000.0  341824.0
# 2      The story of Nil, who misconstrues an enamoure...   3000.0    8581.0
# 3      StrangerComics PRESENTS: Deluxe Fantasy Omnibu...  10000.0   89828.0
# 4      A 100+ Page Horror Anthology. Twelve stories o...  35000.0   10417.0
# ...                                                  ...      ...       ...
# 17991  Legends Hapax is a game that draws on the grea...      0.0       0.0
# 17992  Command mighty warfleets in the battle for Mid...    500.0       0.0
# 17993                              デュアルストーリー型・抜刀剣戟カードゲーム      0.0       0.0
# 17994  A JRPG in which you will go through Eden's jou...      0.0       0.0
# 17995  A heartwarming tabletop rpg of elder lady frie...  25000.0       0.0
#
#            state country country_displayable_name currency  \
# 0           live      US        the United States      USD
# 1           live      GB       the United Kingdom      GBP
# 2           live      US        the United States      USD
# 3           live      US        the United States      USD
# 4           live      US        the United States      USD
# ...          ...     ...                      ...      ...
# 17991  submitted      ES                    Spain      EUR
# 17992    started      US        the United States      USD
# 17993  submitted      JP                    Japan      JPY
# 17994  submitted      FR                   France      EUR
# 17995    started      US        the United States      USD
#
#                  deadline  ... is_launched prelaunch_activated  creator_id  \
# 0     2026-04-30 18:00:05  ...        True                True  1690343815
# 1     2026-04-06 19:00:00  ...        True               False  1378058646
# 2     2026-04-29 19:07:36  ...        True                True   769898516
# 3     2026-04-20 17:01:57  ...        True                True  1182319554
# 4     2026-04-24 02:00:00  ...        True                True  1376978156
# ...                   ...  ...         ...                 ...         ...
# 17991 1970-01-01 00:00:00  ...       False                True   787851171
# 17992 1970-01-01 00:00:00  ...       False                True  1263999445
# 17993 1970-01-01 00:00:00  ...       False                True   437928348
# 17994 1970-01-01 00:00:00  ...       False                True   278762704
# 17995 1970-01-01 00:00:00  ...       False                True  1170592379
#
#                            creator_name  category_id   category_name  \
# 0                         BOOM! Studios          250     Comic Books
# 1                   Lorenzo Etherington            3          Comics
# 2                            Rocketship          252  Graphic Novels
# 3                    Sebastian A. Jones          252  Graphic Novels
# 4      Deathline (from Lifeline Comics)          252  Graphic Novels
# ...                                 ...          ...             ...
# 17991                  Legends of Hapax           35     Video Games
# 17992           Dungeons & Dreadnoughts           34  Tabletop Games
# 17993                  涼宮隼十 / パトスプロジェクト           34  Tabletop Games
# 17994                         ASM-Games           35     Video Games
# 17995                       Ross Cowman           34  Tabletop Games
#
#                category_slug  category_parent_id  category_parent_name  \
# 0         comics/comic books                 3.0                Comics
# 1                     comics                 0.0                     0
# 2      comics/graphic novels                 3.0                Comics
# 3      comics/graphic novels                 3.0                Comics
# 4      comics/graphic novels                 3.0                Comics
# ...                      ...                 ...                   ...
# 17991      games/video games                12.0                 Games
# 17992   games/tabletop games                12.0                 Games
# 17993   games/tabletop games                12.0                 Games
# 17994      games/video games                12.0                 Games
# 17995   games/tabletop games                12.0                 Games
#
#         video_id
# 0            NaN
# 1      1413171.0
# 2      1423417.0
# 3      1421552.0
# 4            NaN
# ...          ...
# 17991        NaN
# 17992        NaN
# 17993        NaN
# 17994        NaN
# 17995        NaN
#
# [16063 rows x 29 columns]
