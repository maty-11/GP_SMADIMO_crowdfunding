# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("out.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13041 entries, 0 to 13040
# Data columns (total 40 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  13041 non-null  int64
#  1   name                                13041 non-null  str
#  2   blurb                               13035 non-null  str
#  3   goal                                13041 non-null  float64
#  4   pledged                             13041 non-null  float64
#  5   state                               13041 non-null  str
#  6   slug                                13041 non-null  str
#  7   country                             13041 non-null  str
#  8   country_displayable_name            13041 non-null  str
#  9   currency                            13041 non-null  str
#  10  currency_symbol                     13041 non-null  str
# ...
